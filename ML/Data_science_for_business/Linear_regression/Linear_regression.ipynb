# %%
import pandas as pd
pd.plotting.register_matplotlib_converters() ## 뭐지?
import matplotlib.pyplot as plt  ## %가 뭐지
# %matplotlib inline 
import seaborn as sns
import os
cwd = os.getcwd()

cwd
# Out:
# 'd:\\git_local_repository\\yangoos57\\kaggle\\Practice\\Mushroom'

# %%
path = 'D:\git_local_repository\yangoos57\kaggle\Practice\Linear_regression\data\Iris.csv'
iris = pd.read_csv(path, index_col='Id')
iris.head(10)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_len_width = iris[['PetalWidthCm','SepalWidthCm','Species']]
iris_len_width
# print(set(iris_len_width['Species']))
# Out:
#      PetalWidthCm  SepalWidthCm         Species
# Id
# 1             0.2           3.5     Iris-setosa
# 2             0.2           3.0     Iris-setosa
# 3             0.2           3.2     Iris-setosa
# 4             0.2           3.1     Iris-setosa
# 5             0.2           3.6     Iris-setosa
# ..            ...           ...             ...
# 146           2.3           3.0  Iris-virginica
# 147           1.9           2.5  Iris-virginica
# 148           2.0           3.0  Iris-virginica
# 149           2.3           3.4  Iris-virginica
# 150           1.8           3.0  Iris-virginica
#
# [150 rows x 3 columns]

# %%
iris_len_width = iris_len_width[iris_len_width['Species'].isin(['Iris-versicolor','Iris-setosa'])]

iris_len_width
# Out:
#      PetalWidthCm  SepalWidthCm          Species
# Id
# 1             0.2           3.5      Iris-setosa
# 2             0.2           3.0      Iris-setosa
# 3             0.2           3.2      Iris-setosa
# 4             0.2           3.1      Iris-setosa
# 5             0.2           3.6      Iris-setosa
# ..            ...           ...              ...
# 96            1.2           3.0  Iris-versicolor
# 97            1.3           2.9  Iris-versicolor
# 98            1.3           2.9  Iris-versicolor
# 99            1.1           2.5  Iris-versicolor
# 100           1.3           2.8  Iris-versicolor
#
# [100 rows x 3 columns]

# %% [markdown]
# **<그림 4-7>**

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=iris_len_width, x='SepalWidthCm', y='PetalWidthCm' , hue ='Species')
plt.ylim(0,2) # y축 범위 설정
plt.xlim(0,5) # y축 범위 설정
# Out:
# (0.0, 5.0)

# %%
print(set(iris.Species))
iris_specis_two = iris[iris['Species'].isin(['Iris-versicolor','Iris-virginica'])]
iris_specis_one = iris.loc[iris['Species'] == 'Iris-versicolor' ]
# Out:
# {'Iris-virginica', 'Iris-setosa', 'Iris-versicolor'}

# %%
sns.pairplot(data=iris_specis_one)
plt.show()

# %%
sns.pairplot(data=iris_specis_two , hue='Species')
plt.show()

# %%
sns.pairplot(data=iris_specis_two , hue='Species')
plt.show()
