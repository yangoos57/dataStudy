# %%
import numpy as np
import os
import imageio  # scipy에서 imread은 이제 사라짐 
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline 
print('No Error')
# Out:
# No Error

# %%
cwd = os.getcwd()
print(f'current folder is  [{cwd}]')
# Out:
# current folder is  [d:\git_local_repository\yangoos57\ML\ML lec\choi sungjoon-edwith]

# %%
hamster = Image.open('./data/hamster.jpg')
hamster.show()

# %%
plt.figure(figsize=(10,8))
plt.imshow(hamster)
plt.title('I love the hamster')
plt.draw()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-ebef75e339d8> in <module>
# ----> 1 hamster_2 = Image.open('./data/hamster.jpg').astype(np.float)/255.
#
# AttributeError: 'JpegImageFile' object has no attribute 'astype'
